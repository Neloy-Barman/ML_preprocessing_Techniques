# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("music_emotion_classification.csv")

# %%
data.head()
# Out:
#    Class  _RMSenergy_Mean  _Lowenergy_Mean  _Fluctuation_Mean  _Tempo_Mean  \
# 0  relax            0.052            0.591              9.136      130.043
# 1  relax            0.125            0.439              6.680      142.240
# 2  relax            0.046            0.639             10.578      188.154
# 3  relax            0.135            0.603             10.442       65.991
# 4  relax            0.066            0.591              9.769       88.890
#
#    _MFCC_Mean_1  _MFCC_Mean_2  _MFCC_Mean_3  _MFCC_Mean_4  _MFCC_Mean_5  ...  \
# 0         3.997         0.363         0.887         0.078         0.221  ...
# 1         4.058         0.516         0.785         0.397         0.556  ...
# 2         2.775         0.903         0.502         0.329         0.287  ...
# 3         2.841         1.552         0.612         0.351         0.011  ...
# 4         3.217         0.228         0.814         0.096         0.434  ...
#
# ...

# %%
Column_list = data.columns
print(f"{Column_list}")
# Out:
# Index(['Class', '_RMSenergy_Mean', '_Lowenergy_Mean', '_Fluctuation_Mean',
#        '_Tempo_Mean', '_MFCC_Mean_1', '_MFCC_Mean_2', '_MFCC_Mean_3',
#        '_MFCC_Mean_4', '_MFCC_Mean_5', '_MFCC_Mean_6', '_MFCC_Mean_7',
#        '_MFCC_Mean_8', '_MFCC_Mean_9', '_MFCC_Mean_10', '_MFCC_Mean_11',
#        '_MFCC_Mean_12', '_MFCC_Mean_13', '_Roughness_Mean', '_Roughness_Slope',
#        '_Zero-crossingrate_Mean', '_AttackTime_Mean', '_AttackTime_Slope',
#        '_Rolloff_Mean', '_Eventdensity_Mean', '_Pulseclarity_Mean',
#        '_Brightness_Mean', '_Spectralcentroid_Mean', '_Spectralspread_Mean',
#        '_Spectralskewness_Mean', '_Spectralkurtosis_Mean',
#        '_Spectralflatness_Mean', '_EntropyofSpectrum_Mean',
#        '_Chromagram_Mean_1', '_Chromagram_Mean_2', '_Chromagram_Mean_3',
#        '_Chromagram_Mean_4', '_Chromagram_Mean_5', '_Chromagram_Mean_6',
#        '_Chromagram_Mean_7', '_Chromagram_Mean_8', '_Chromagram_Mean_9',
# ...

# %%
data.describe()
# Out:
#        _RMSenergy_Mean  _Lowenergy_Mean  _Fluctuation_Mean  _Tempo_Mean  \
# count       400.000000       400.000000         400.000000   400.000000
# mean          0.134650         0.553605           7.145932   123.682020
# std           0.064368         0.050750           2.280145    34.234344
# min           0.010000         0.302000           3.580000    48.284000
# 25%           0.085000         0.523000           5.859500   101.490250
# 50%           0.128000         0.553000           6.734000   120.132500
# 75%           0.174000         0.583250           7.823500   148.986250
# max           0.431000         0.703000          23.475000   195.026000
#
#        _MFCC_Mean_1  _MFCC_Mean_2  _MFCC_Mean_3  _MFCC_Mean_4  _MFCC_Mean_5  \
# count    400.000000    400.000000    400.000000    400.000000    400.000000
# mean       2.456422      0.071890      0.488065      0.030465      0.178898
# std        0.799262      0.537865      0.294607      0.275839      0.195230
# ...

# %%
data.isna().sum()
# Out:
# Class                                             0
# _RMSenergy_Mean                                   0
# _Lowenergy_Mean                                   0
# _Fluctuation_Mean                                 0
# _Tempo_Mean                                       0
# _MFCC_Mean_1                                      0
# _MFCC_Mean_2                                      0
# _MFCC_Mean_3                                      0
# _MFCC_Mean_4                                      0
# _MFCC_Mean_5                                      0
# _MFCC_Mean_6                                      0
# _MFCC_Mean_7                                      0
# _MFCC_Mean_8                                      0
# _MFCC_Mean_9                                      0
# _MFCC_Mean_10                                     0
# _MFCC_Mean_11                                     0
# _MFCC_Mean_12                                     0
# _MFCC_Mean_13                                     0
# ...

# %%
data.dtypes
# Out:
# Class                                              object
# _RMSenergy_Mean                                   float64
# _Lowenergy_Mean                                   float64
# _Fluctuation_Mean                                 float64
# _Tempo_Mean                                       float64
# _MFCC_Mean_1                                      float64
# _MFCC_Mean_2                                      float64
# _MFCC_Mean_3                                      float64
# _MFCC_Mean_4                                      float64
# _MFCC_Mean_5                                      float64
# _MFCC_Mean_6                                      float64
# _MFCC_Mean_7                                      float64
# _MFCC_Mean_8                                      float64
# _MFCC_Mean_9                                      float64
# _MFCC_Mean_10                                     float64
# _MFCC_Mean_11                                     float64
# ...

# %% [markdown]
# ## **`Column normalization`**

# %%
def column_normalization(frame, column_name):
    """
    It takes the frame and column_name as input and returns us with the normalized column 
    placed in the frame.
    """
    if frame[column_name].min() >= 0.00 and frame[column_name].max() <= 1.00:
        return frame
    else:
        frame[column_name] = (frame[column_name] - frame[column_name].mean()) / frame[column_name].std()
        frame[column_name] = (frame[column_name] - frame[column_name].min()) / (frame[column_name].max() - frame[column_name].min())
        return frame

# %% [markdown]
# ## **`Normalizing the frame`**

# %%
def normalize_frame(frame, column_list):
    """
    It takes the frame and column_list as input and normalizes the column values using 
    column_normalization function.
    
    """
    for i in range(len(column_list)):
        frame = column_normalization(frame, column_list[i])
    return frame

# %%
# The column index contains prediction class as that's not necessary so, it's dropped. 
data = data.drop(["Class"], axis=1)
Column_list = data.columns
print(f"{Column_list}")
# Out:
# Index(['_RMSenergy_Mean', '_Lowenergy_Mean', '_Fluctuation_Mean',
#        '_Tempo_Mean', '_MFCC_Mean_1', '_MFCC_Mean_2', '_MFCC_Mean_3',
#        '_MFCC_Mean_4', '_MFCC_Mean_5', '_MFCC_Mean_6', '_MFCC_Mean_7',
#        '_MFCC_Mean_8', '_MFCC_Mean_9', '_MFCC_Mean_10', '_MFCC_Mean_11',
#        '_MFCC_Mean_12', '_MFCC_Mean_13', '_Roughness_Mean', '_Roughness_Slope',
#        '_Zero-crossingrate_Mean', '_AttackTime_Mean', '_AttackTime_Slope',
#        '_Rolloff_Mean', '_Eventdensity_Mean', '_Pulseclarity_Mean',
#        '_Brightness_Mean', '_Spectralcentroid_Mean', '_Spectralspread_Mean',
#        '_Spectralskewness_Mean', '_Spectralkurtosis_Mean',
#        '_Spectralflatness_Mean', '_EntropyofSpectrum_Mean',
#        '_Chromagram_Mean_1', '_Chromagram_Mean_2', '_Chromagram_Mean_3',
#        '_Chromagram_Mean_4', '_Chromagram_Mean_5', '_Chromagram_Mean_6',
#        '_Chromagram_Mean_7', '_Chromagram_Mean_8', '_Chromagram_Mean_9',
# ...

# %%
Normalized_frame = normalize_frame(data, Column_list)

# %%
Normalized_frame.to_csv("N_Music_Emotion.csv")

# %%
Normalized_frame.head()
# Out:
#    _RMSenergy_Mean  _Lowenergy_Mean  _Fluctuation_Mean  _Tempo_Mean  \
# 0            0.052            0.591           0.279266     0.557162
# 1            0.125            0.439           0.155818     0.640280
# 2            0.046            0.639           0.351747     0.953170
# 3            0.135            0.603           0.344911     0.120668
# 4            0.066            0.591           0.311083     0.276717
#
#    _MFCC_Mean_1  _MFCC_Mean_2  _MFCC_Mean_3  _MFCC_Mean_4  _MFCC_Mean_5  \
# 0      0.647629      0.709648      0.705056      0.620565      0.461588
# 1      0.658382      0.737871      0.664125      0.736061      0.677857
# 2      0.432223      0.809260      0.550562      0.711441      0.504196
# 3      0.443857      0.928980      0.594703      0.719406      0.326017
# 4      0.510136      0.684745      0.675762      0.627082      0.599096
#
#    _MFCC_Mean_6  ...  _Chromagram_Mean_9  _Chromagram_Mean_10  \
# ...

# %%
Normalized_frame.describe()
# Out:
#        _RMSenergy_Mean  _Lowenergy_Mean  _Fluctuation_Mean  _Tempo_Mean  \
# count       400.000000       400.000000         400.000000   400.000000
# mean          0.134650         0.553605           0.179238     0.513813
# std           0.064368         0.050750           0.114609     0.233296
# min           0.010000         0.302000           0.000000     0.000000
# 25%           0.085000         0.523000           0.114577     0.362584
# 50%           0.128000         0.553000           0.158532     0.489625
# 75%           0.174000         0.583250           0.213295     0.686254
# max           0.431000         0.703000           1.000000     1.000000
#
#        _MFCC_Mean_1  _MFCC_Mean_2  _MFCC_Mean_3  _MFCC_Mean_4  _MFCC_Mean_5  \
# count    400.000000    400.000000    400.000000    400.000000    400.000000
# mean       0.376066      0.655947      0.544970      0.603354      0.434408
# std        0.140889      0.099219      0.118221      0.099869      0.126036
# ...
